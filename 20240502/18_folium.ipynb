# %%
# folium은 Leaflet.js를 이용해서 위치 좌표계 값을 지도위 시각화 할 수 있다.
import folium

# %%
# folium의 Map 클래스의 location 속성으로 지정한 위치를 중심으로 하는 zoom_start 속성으로 지정한 배율을
# 사용하는 지도를 만든다.
# folium.Map(location=[위도, 경도], zoom_start=배율)
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=16)
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_293acc3344fa2273d6ec42ee65a70aa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_293acc3344fa2273d6ec42ee65a70aa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_293acc3344fa2273d6ec42ee65a70aa6 = L.map(
#                 &quot;map_293acc3344fa2273d6ec42ee65a70aa6&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 16,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d418286dc2474749f2a6394a47551ea9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_293acc3344fa2273d6ec42ee65a70aa6);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# folium의 Marker 클래스의 location 속성으로 지정한 위치에 마커를 만든다.
# 마커는 add_to() 메소드로 지도에 추가한다.
# folium의 Marker 클래스의 popup 속성으로 마커를 클릭했을 때 표시할 문자열을 지정할 수 있다.
folium.Marker(location=[37.57961628, 126.97704096], popup='경복궁').add_to(folium_map)
folium.Marker(location=[37.56580575, 126.97514357], popup='덕수궁').add_to(folium_map)
folium.Marker(location=[37.5787512, 126.9948775], popup='창경궁').add_to(folium_map)
folium.Marker(location=[37.57943211, 126.99104354], popup='창덕궁').add_to(folium_map)
folium.Marker(location=[37.57373256, 126.9937536], popup='종묘').add_to(folium_map)

# 마커를 클릭했을 때 팝업되는 말풍선 크기는 folium의 Popup 클래스의 max_width 속성으로 지정할 수 있다.
popup = folium.Popup('영풍문고 - 종로본점', max_width=200)
folium.Marker(location=[37.56978693, 126.98231618], popup=popup).add_to(folium_map)

# save() 메소드로 지도를 html 파일로 저장할 수 있다.
folium_map.save('./output/folium_map.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e40dcba2ed4fd080f60dd1db58e07337 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e40dcba2ed4fd080f60dd1db58e07337&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e40dcba2ed4fd080f60dd1db58e07337 = L.map(
#                 &quot;map_e40dcba2ed4fd080f60dd1db58e07337&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c9fe37d2f9e34849b312aeabe4311bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#             var marker_caabd77c4db6feb9d6ad9ab7a8e4542c = L.marker(
#                 [37.57961628, 126.97704096],
#                 {}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#         var popup_041ddfc122a78743909b9d4b247ef11a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86184cb5170e2d5106aa535e61f1bc90 = $(`&lt;div id=&quot;html_86184cb5170e2d5106aa535e61f1bc90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_041ddfc122a78743909b9d4b247ef11a.setContent(html_86184cb5170e2d5106aa535e61f1bc90);
#
#
#
#         marker_caabd77c4db6feb9d6ad9ab7a8e4542c.bindPopup(popup_041ddfc122a78743909b9d4b247ef11a)
#         ;
#
#
#
#
#             var marker_4c9997234ecfcf5f3f9bb6b91d14027b = L.marker(
#                 [37.56580575, 126.97514357],
#                 {}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#         var popup_2ad17f50d7526c91d5640df3e7f0148c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6bc20e5bd1cf9547a2cfb229babd4a3a = $(`&lt;div id=&quot;html_6bc20e5bd1cf9547a2cfb229babd4a3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_2ad17f50d7526c91d5640df3e7f0148c.setContent(html_6bc20e5bd1cf9547a2cfb229babd4a3a);
#
#
#
#         marker_4c9997234ecfcf5f3f9bb6b91d14027b.bindPopup(popup_2ad17f50d7526c91d5640df3e7f0148c)
#         ;
#
#
#
#
#             var marker_f0d93510879f768d9e80d432244c243e = L.marker(
#                 [37.5787512, 126.9948775],
#                 {}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#         var popup_966ffeb109c19f95a7cc778e72bc31b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72aac71d2aa9cf7e7c473a13a88edcf1 = $(`&lt;div id=&quot;html_72aac71d2aa9cf7e7c473a13a88edcf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창경궁&lt;/div&gt;`)[0];
#                 popup_966ffeb109c19f95a7cc778e72bc31b6.setContent(html_72aac71d2aa9cf7e7c473a13a88edcf1);
#
#
#
#         marker_f0d93510879f768d9e80d432244c243e.bindPopup(popup_966ffeb109c19f95a7cc778e72bc31b6)
#         ;
#
#
#
#
#             var marker_d869cd8d072a38d47bf0ca5f0698f9bc = L.marker(
#                 [37.57943211, 126.99104354],
#                 {}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#         var popup_b0a1e4c08df8f8493e06742314ac080f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_71690581d017181483577910b87af24b = $(`&lt;div id=&quot;html_71690581d017181483577910b87af24b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창덕궁&lt;/div&gt;`)[0];
#                 popup_b0a1e4c08df8f8493e06742314ac080f.setContent(html_71690581d017181483577910b87af24b);
#
#
#
#         marker_d869cd8d072a38d47bf0ca5f0698f9bc.bindPopup(popup_b0a1e4c08df8f8493e06742314ac080f)
#         ;
#
#
#
#
#             var marker_42247a4d32fa3d5754a64bab5082efd5 = L.marker(
#                 [37.57373256, 126.9937536],
#                 {}
#             ).addTo(map_e40dcba2ed4fd080f60dd1db58e07337);
#
#
#         var popup_9efa763bad1508c02416101ef3711cad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f74d9878a2fb2512650031f9ec46b92c = $(`&lt;div id=&quot;html_f74d9878a2fb2512650031f9ec46b92c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종묘&lt;/div&gt;`)[0];
#                 popup_9efa763bad1508c02416101ef3711cad.setContent(html_f74d9878a2fb2512650031f9ec46b92c);
#
#
#
#         marker_42247a4d32fa3d5754a64bab5082efd5.bindPopup(popup_9efa763bad1508c02416101ef3711cad)
#         ;
#
#
#
#
#             var marker_81f72583103e46d62b032e03e110a987 = L.marker(
#                 [37.56978693, 126.98231618],
#                 {}
#             ).addT

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# folium의 Icon 클래스의 color 속성으로 마커의 색상과 icon 속성으로 아이콘 모양을 지정할 수 있다.
# 마커 색생과 아이콘 모양을 변경하려면 folium의 Marker 클래스의 icon 속성에 Icon 객체를 지정하면 된다.
# 색상 이름 리스트
# 'darkred', 'pink', 'gray', 'cadetblue', 'purple', 'lightgray', 'red', 'beige', 'orange', 'blue', 'black', 
# 'white', 'darkblue', 'lightgreen', 'lightblue', 'darkpurple', 'darkgreen', 'green', 'lightred'
# 마커에 표시할 아이콘은 https://getbootstrap.com/docs/3.3/components/#glyphicons-glyph에서 제공하는 
# 아이콘을 표시할 수 있다.

folium.Marker(location=[37.57961628, 126.97704096], popup='경복궁',
             icon=folium.Icon(color='pink', icon='ok')).add_to(folium_map)
folium.Marker(location=[37.56580575, 126.97514357], popup='덕수궁',
             icon=folium.Icon(color='beige', icon='remove')).add_to(folium_map)
folium.Marker(location=[37.5787512, 126.9948775], popup='창경궁',
             icon=folium.Icon(color='orange', icon='tag')).add_to(folium_map)
folium.Marker(location=[37.57943211, 126.99104354], popup='창덕궁',
             icon=folium.Icon(color='cadetblue', icon='arrow-up')).add_to(folium_map)
folium.Marker(location=[37.57373256, 126.9937536], popup='종묘',
             icon=folium.Icon(color='purple', icon='hand-down')).add_to(folium_map)

popup = folium.Popup('영풍문고 - 종로본점', max_width=200)
folium.Marker(location=[37.56978693, 126.98231618], popup=popup,
             icon=folium.Icon(color='green', icon='chevron-down')).add_to(folium_map)

folium_map.save('./output/folium_map2.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b4a20651b021f101831d751516ff37f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b4a20651b021f101831d751516ff37f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b4a20651b021f101831d751516ff37f = L.map(
#                 &quot;map_6b4a20651b021f101831d751516ff37f&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5d8d8e822b60a944946c0e031ba7d4c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6b4a20651b021f101831d751516ff37f);
#
#
#             var marker_6fd82e5c2c5b3b758ecf4b6e3c7796ec = L.marker(
#                 [37.57961628, 126.97704096],
#                 {}
#             ).addTo(map_6b4a20651b021f101831d751516ff37f);
#
#
#             var icon_de93a43d543ee0eea8f2fa36e74f1d0d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fd82e5c2c5b3b758ecf4b6e3c7796ec.setIcon(icon_de93a43d543ee0eea8f2fa36e74f1d0d);
#
#
#         var popup_1dfaf7db28ceb85a2ad4252380941970 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8ff03c379ea593614a997b6d6d6198cd = $(`&lt;div id=&quot;html_8ff03c379ea593614a997b6d6d6198cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_1dfaf7db28ceb85a2ad4252380941970.setContent(html_8ff03c379ea593614a997b6d6d6198cd);
#
#
#
#         marker_6fd82e5c2c5b3b758ecf4b6e3c7796ec.bindPopup(popup_1dfaf7db28ceb85a2ad4252380941970)
#         ;
#
#
#
#
#             var marker_4a66a029c9646c39f2b79345bdb31276 = L.marker(
#                 [37.56580575, 126.97514357],
#                 {}
#             ).addTo(map_6b4a20651b021f101831d751516ff37f);
#
#
#             var icon_36277d07e4e29797675a299150347ac7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;remove&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;beige&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4a66a029c9646c39f2b79345bdb31276.setIcon(icon_36277d07e4e29797675a299150347ac7);
#
#
#         var popup_2647f2bd0066ec108d6143d21595167c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_099dfe04d56d386d0acc80ffa8ac5800 = $(`&lt;div id=&quot;html_099dfe04d56d386d0acc80ffa8ac5800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_2647f2bd0066ec108d6143d21595167c.setContent(html_099dfe04d56d386d0acc80ffa8ac5800);
#
#
#
#         marker_4a66a029c9646c39f2b79345bdb31276.bindPopup(popup_2647f2bd0066ec108d6143d21595167c)
#         ;
#
#
#
#
#             var marker_21d91ffcd538b69d18390fdf15187450 = L.marker(
#                 [37.5787512, 126.9948775],
#                 {}
#             ).addTo(map_6b4a20651b021f101831d751516ff37f);
#
#
#             var icon_0fde82209af1a73e348be0622e0d33fc = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;tag&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_21d91ffcd538b69d18390fdf15187450.setIcon(icon_0fde82209af1a73e348be0622e0d33fc);
#
#
#         var popup_58be772e50431b486d26c889efb0dbce = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c9008efbcc2fc1cddc630b0e151d1ff = $(`&lt;div id=&quot;html_2c9008efbcc2fc1cddc630b0e151d1ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창경궁&lt;/div&gt;`)[0];
#                 popup_58be772e50431b486d26c889efb0dbce.setContent(html_2c9008efbcc2fc1cddc630b0e151d1ff);
#
#
#
#         marker_21d91ffcd538b69d18390fdf15187450.bindPopup(popup_58be772e50431b486d26c889efb0dbce)
#         ;
#
#
#
#
#             var marker_3b80b7a5113de8aae73838feec48702b = L.marker(
#                 [37.57943211, 126.99104354],
#                 {}
#             ).addTo(map_6b4a20651b021f101831d751516ff37f);
#
#
#             var icon_68f73b642141d013dce1794764da2b08 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;arrow-up&quot;, &quot;ic

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# folium의 CircleMarker 클래스로 원형 마커를 만들 수 있다.
# radius 속성으로 마커로 표시되는 원의 반지름을 지정한다.
# color 속성으로 원의 선 색상을 fill_color 속성으로 원 내부의 채울 색상을 지정할 수 있다.

folium.CircleMarker(location=[37.57961628, 126.97704096], popup='경복궁',
                   radius=100, color='red', fill_color='blue').add_to(folium_map)
popup = folium.Popup('영풍문고 - 종로본점', max_width=200)
folium.CircleMarker(location=[37.56978693, 126.98231618], popup=popup, 
                    radius=50, color='#00ffff', fill_color='#ff00ff').add_to(folium_map)

folium_map.save('./output/folium_map3.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fcf1a021b031198fd9c669bd9a76fd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fcf1a021b031198fd9c669bd9a76fd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fcf1a021b031198fd9c669bd9a76fd6 = L.map(
#                 &quot;map_5fcf1a021b031198fd9c669bd9a76fd6&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_016ea89ed5fd50a8de2f4ac6f4922032 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fcf1a021b031198fd9c669bd9a76fd6);
#
#
#             var circle_marker_d944b68988f89e70e5aef729753a4c88 = L.circleMarker(
#                 [37.57961628, 126.97704096],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fcf1a021b031198fd9c669bd9a76fd6);
#
#
#         var popup_cec4c17ef0c75bcd68557319a2184849 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1c3107d83d20cf26f5656e33a85f950e = $(`&lt;div id=&quot;html_1c3107d83d20cf26f5656e33a85f950e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_cec4c17ef0c75bcd68557319a2184849.setContent(html_1c3107d83d20cf26f5656e33a85f950e);
#
#
#
#         circle_marker_d944b68988f89e70e5aef729753a4c88.bindPopup(popup_cec4c17ef0c75bcd68557319a2184849)
#         ;
#
#
#
#
#             var circle_marker_6d87ad074f541d1e974a4f2717df0c7e = L.circleMarker(
#                 [37.56978693, 126.98231618],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#00ffff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5fcf1a021b031198fd9c669bd9a76fd6);
#
#
#         var popup_c7543b0f349c12223dd552c6c3329455 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_fe17733e476508ad6749f22abd559067 = $(`&lt;div id=&quot;html_fe17733e476508ad6749f22abd559067&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고 - 종로본점&lt;/div&gt;`)[0];
#                 popup_c7543b0f349c12223dd552c6c3329455.setContent(html_fe17733e476508ad6749f22abd559067);
#
#
#
#         circle_marker_6d87ad074f541d1e974a4f2717df0c7e.bindPopup(popup_c7543b0f349c12223dd552c6c3329455)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
